# %% [markdown]
# <a href="https://colab.research.google.com/github/ansarimaaz05/AI-CODE-EXPLAINER/blob/main/deeplearning_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Deep Learning Practical Task - GAN & Autoencoder
# Google Colab Notebook

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models

# -----------------------------
# 1. Load Dataset (MNIST)
# -----------------------------
(x_train, _), (x_test, _) = tf.keras.datasets.mnist.load_data()
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# -----------------------------
# 2. Autoencoder for Denoising
# -----------------------------
noise_factor = 0.4
x_train_noisy = x_train + noise_factor * np.random.normal(size=x_train.shape)
x_test_noisy = x_test + noise_factor * np.random.normal(size=x_test.shape)
x_train_noisy = np.clip(x_train_noisy, 0., 1.)
x_test_noisy = np.clip(x_test_noisy, 0., 1.)

input_img = layers.Input(shape=(28,28,1))
x = layers.Conv2D(32, (3,3), activation="relu", padding="same")(input_img)
x = layers.MaxPooling2D((2,2), padding="same")(x)
x = layers.Conv2D(32, (3,3), activation="relu", padding="same")(x)
encoded = layers.MaxPooling2D((2,2), padding="same")(x)

x = layers.Conv2D(32, (3,3), activation="relu", padding="same")(encoded)
x = layers.UpSampling2D((2,2))(x)
x = layers.Conv2D(32, (3,3), activation="relu", padding="same")(x)
x = layers.UpSampling2D((2,2))(x)
decoded = layers.Conv2D(1, (3,3), activation="sigmoid", padding="same")(x)

autoencoder = models.Model(input_img, decoded)
autoencoder.compile(optimizer="adam", loss="binary_crossentropy")
autoencoder.summary()

# Train Autoencoder
autoencoder.fit(x_train_noisy, x_train,
                epochs=5,
                batch_size=128,
                shuffle=True,
                validation_data=(x_test_noisy, x_test))

# Show Denoising Results
decoded_imgs = autoencoder.predict(x_test_noisy[:10])
plt.figure(figsize=(20,4))
for i in range(10):
    # Original noisy
    ax = plt.subplot(3,10,i+1)
    plt.imshow(x_test_noisy[i].reshape(28,28), cmap="gray")
    plt.axis("off")
    # Reconstructed
    ax = plt.subplot(3,10,i+1+10)
    plt.imshow(decoded_imgs[i].reshape(28,28), cmap="gray")
    plt.axis("off")
    # Original clean
    ax = plt.subplot(3,10,i+1+20)
    plt.imshow(x_test[i].reshape(28,28), cmap="gray")
    plt.axis("off")
plt.show()

# -----------------------------
# 3. Simple GAN
# -----------------------------
latent_dim = 100

# Generator
generator = models.Sequential([
    layers.Dense(7*7*128, input_dim=latent_dim),
    layers.LeakyReLU(0.2),
    layers.Reshape((7,7,128)),
    layers.Conv2DTranspose(128, (4,4), strides=(2,2), padding="same"),
    layers.LeakyReLU(0.2),
    layers.Conv2DTranspose(128, (4,4), strides=(2,2), padding="same"),
    layers.LeakyReLU(0.2),
    layers.Conv2D(1, (7,7), activation="sigmoid", padding="same")
])

# Discriminator
discriminator = models.Sequential([
    layers.Conv2D(64, (3,3), strides=(2,2), padding="same", input_shape=(28,28,1)),
    layers.LeakyReLU(0.2),
    layers.Dropout(0.3),
    layers.Conv2D(64, (3,3), strides=(2,2), padding="same"),
    layers.LeakyReLU(0.2),
    layers.Dropout(0.3),
    layers.Flatten(),
    layers.Dense(1, activation="sigmoid")
])
discriminator.compile(optimizer="adam", loss="binary_crossentropy")

# GAN
discriminator.trainable = False
gan_input = layers.Input(shape=(latent_dim,))
fake_img = generator(gan_input)
gan_output = discriminator(fake_img)
gan = models.Model(gan_input, gan_output)
gan.compile(optimizer="adam", loss="binary_crossentropy")

# Training loop (simplified)
def train_gan(epochs=1000, batch_size=128):
    for epoch in range(epochs):
        # Train discriminator
        idx = np.random.randint(0, x_train.shape[0], batch_size)
        real_imgs = x_train[idx]
        noise = np.random.normal(0,1,(batch_size, latent_dim))
        fake_imgs = generator.predict(noise)

        d_loss_real = discriminator.train_on_batch(real_imgs, np.ones((batch_size,1)))
        d_loss_fake = discriminator.train_on_batch(fake_imgs, np.zeros((batch_size,1)))

        # Train GAN (generator)
        noise = np.random.normal(0,1,(batch_size, latent_dim))
        g_loss = gan.train_on_batch(noise, np.ones((batch_size,1)))

        if epoch % 200 == 0:
            print(f"Epoch {epoch}, D Loss: {0.5*np.add(d_loss_real,d_loss_fake)}, G Loss: {g_loss}")
            show_generated_images(epoch)

def show_generated_images(epoch, examples=10):
    noise = np.random.normal(0,1,(examples, latent_dim))
    gen_imgs = generator.predict(noise)
    plt.figure(figsize=(10,2))
    for i in range(examples):
        plt.subplot(1,examples,i+1)
        plt.imshow(gen_imgs[i].reshape(28,28), cmap="gray")
        plt.axis("off")
    plt.suptitle(f"Generated Images at Epoch {epoch}")
    plt.show()

# Run GAN training
train_gan(epochs=1000, batch_size=256)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 28, 28, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 14, 14, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 7, 7, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 7, 7, 32)       │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 14, 14, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 14, 14, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 28, 28, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 28, 28, 1)      │           289 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,353 (110.75 KB)
#  Trainable params: 28,353 (110.75 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 141s 296ms/step - loss: 0.2427 - val_loss: 0.1038
# Epoch 2/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 127s 271ms/step - loss: 0.1025 - val_loss: 0.0958
# Epoch 3/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 126s 269ms/step - loss: 0.0959 - val_loss: 0.0928
# Epoch 4/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 127s 270ms/step - loss: 0.0934 - val_loss: 0.0911
# Epoch 5/5
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 130s 244ms/step - loss: 0.0916 - val_loss: 0.0903
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py:83: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# Epoch 0, D Loss: 0.6868531107902527, G Loss: 0.6582112312316895
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 175ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 166ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 242ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 236ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 219ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 239ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 235ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 238ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step
